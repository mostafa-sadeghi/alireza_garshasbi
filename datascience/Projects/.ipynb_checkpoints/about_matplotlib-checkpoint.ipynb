# %% [markdown]
# <img src="apple.jpg" height="200" width="220"/>

# %%
from matplotlib.image import imread

# %%
apple = imread("apple.jpg")

# %%
apple
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
type(apple)
# Out:
# numpy.ndarray

# %%
apple.size
# Out:
# 6750000

# %%
apple.shape
# Out:
# (1500, 1500, 3)

# %%
apple[1100]
# Out:
# array([[255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        ...,
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255]], dtype=uint8)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x = [1,2,3,4,5]
y = [11,12,33,44,55]
z = [11,12,33,44,55]
plt.plot(x,y)
plt.show()

# %%
fig, ((ax1,ax2),(ax3,ax4),(ax5,ax6)) = plt.subplots(nrows=3, ncols=2, figsize=(10,5))
ax1.plot(x,y)
ax2.scatter(x,y)
ax3.pie(x)
ax4.hist(y)
ax5.bar(x,x)
# Out:
# <BarContainer object of 5 artists>

# %%
car_sales = pd.read_csv("exported_car_sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"]  = car_sales["Price"].str.replace('[\$\,\.]','').astype(int)
car_sales
# Out:
# C:\Users\msa\AppData\Local\Temp\ipykernel_15256\3461849379.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"]  = car_sales["Price"].str.replace('[\$\,\.]','').astype(int)
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
import pandas as pd
import numpy as np

# %%
cars_sales = pd.read_csv("exported_car_sales.csv")
cars_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2023", periods = 1000))

# %%
ts
# Out:
# 2023-01-01   -1.359756
# 2023-01-02    0.434367
# 2023-01-03    0.788314
# 2023-01-04    0.639796
# 2023-01-05   -0.948489
#                 ...
# 2025-09-22    0.081288
# 2025-09-23   -2.297395
# 2025-09-24    1.260903
# 2025-09-25    0.568918
# 2025-09-26   -1.497735
# Freq: D, Length: 1000, dtype: float64

# %%
#ts = ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot: >

# %%
cars_sales["Price"]  = cars_sales["Price"].str.replace('[\$\,\.]','').astype(int)
# Out:
# C:\Users\msa\AppData\Local\Temp\ipykernel_3076\1487838596.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   cars_sales["Price"]  = cars_sales["Price"].str.replace('[\$\,\.]','').astype(int)

# %%
cars_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
cars_sales["Sale date"] = pd.date_range("1/1/2023",freq = "3M")
cars_sales
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 cars_sales["Sale date"] = pd.date_range("1/1/2023", "3/1/2023",freq = "3d")
#       2 cars_sales
#
# File E:\NIKLEARNING\projects\monday\alirezagarshasbi\datascience\env\lib\site-packages\pandas\core\frame.py:3978, in DataFrame.__setitem__(self, key, value)
#    3975     self._setitem_array([key], value)
#    3976 else:
#    3977     # set column
# -> 3978     self._set_item(key, value)
#
# File E:\NIKLEARNING\projects\monday\alirezagarshasbi\datascience\env\lib\site-packages\pandas\core\frame.py:4172, in DataFrame._set_item(self, key, value)
#    4162 def _set_item(self, key, value) -> None:
#    4163     """
#    4164     Add series to DataFrame in specified column.
#    4165
#    (...)
#    4170     ensure homogeneity.
#    4171     """
# -> 4172     value = self._sanitize_column(value)
#    4174     if (
#    4175         key in self.columns
#    4176         and value.ndim == 1
#    4177         and not is_extension_array_dtype(value)
#    4178     ):
#    4179         # broadcast across multiple columns if necessary
#    4180         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File E:\NIKLEARNING\projects\monday\alirezagarshasbi\datascience\env\lib\site-packages\pandas\core\frame.py:4912, in DataFrame._sanitize_column(self, value)
#    4909     return _reindex_for_setitem(Series(value), self.index)
#    4911 if is_list_like(value):
# -> 4912     com.require_length_match(value, self.index)
#    4913 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File E:\NIKLEARNING\projects\monday\alirezagarshasbi\datascience\env\lib\site-packages\pandas\core\common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (20) does not match length of index (10)
